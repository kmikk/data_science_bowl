# %%
import warnings
import sys
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsClassifier

# %%
url = "resources/olg_solar_weather.csv"
fiveaxis = pd.read_csv(url)
fiveaxis = fiveaxis.fillna(0)
fiveaxis.head(100)
# Out:
#               date_time  power_delivered  energy_delivered  cumulative_energy  \
# 0   2019-04-21 13:00:00            57444             14361              22937
# 1   2019-04-21 14:00:00            74580             18645              41582
# 2   2019-04-21 15:00:00            72024             18006              59588
# 3   2019-04-21 16:00:00            63552             15888              75476
# 4   2019-04-21 17:00:00            45996             11499              86975
# ..                  ...              ...               ...                ...
# 95  2019-04-25 12:00:00            58888             14722             391819
# 96  2019-04-25 13:00:00            78860             19715             411534
# 97  2019-04-25 14:00:00            86384             21596             433130
# 98  2019-04-25 15:00:00            85476             21369             454499
# 99  2019-04-25 16:00:00            76732             19183             473682
#
# ...

# %%
col = list(fiveaxis.columns)
# print(col)

# %%
print(col)
# Out:
# ['date_time', 'power_delivered', 'energy_delivered', 'cumulative_energy', 'weather_description', 'clouds_all', 'temp_f', 'rain_1h', 'snow_1h', 'hour', 'day', 'month']

# %%
col = ['energy_delivered', 'cumulative_energy', 'clouds_all', 'temp_f', 'rain_1h', 'snow_1h', 'hour', 'day', 'month']

# %%
fiveaxis.describe()
# Out:
#        power_delivered  energy_delivered  cumulative_energy   clouds_all  \
# count      2582.000000       2582.000000       2.582000e+03  2582.000000
# mean      20776.254067       5194.063517       6.476571e+06    41.489930
# std       27616.794372       6904.198593       3.916135e+06    37.201501
# min           0.000000          0.000000       2.293700e+04     0.000000
# 25%           0.000000          0.000000       3.132624e+06     1.000000
# 50%        5160.000000       1290.000000       6.581914e+06    40.000000
# 75%       37377.000000       9344.250000       9.714027e+06    75.000000
# max       88816.000000      22204.000000       1.342216e+07   100.000000
#
#             temp_f      rain_1h  snow_1h         hour          day  \
# count  2582.000000  2582.000000   2582.0  2582.000000  2582.000000
# mean     64.384651     0.156081      0.0    11.513555    16.010070
# std      12.410933     0.531860      0.0     6.931810     9.225526
# ...

# %%
y = fiveaxis['power_delivered']

# %%
# create bins for power_delivered
# labels = ['0', '<1000', '1000-2000', '2000-3000', '3000-4000', '4000-5000']
labels = range(0, 2)
mpls_power_bins = pd.cut(fiveaxis.power_delivered,
                         [-1, 0],
                         labels=labels)
mpls_power_bins.fillna(0, inplace=True)
mpls_power_bins.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: power_delivered, dtype: category
# Categories (1, int64): [0]

# %%
for i in col:
    try:
        current = i
        newlist = list(filter(lambda x: x != i, col))
        X = fiveaxis[newlist]
        y = fiveaxis[current].values.reshape(-1,1)
        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#         X_scaler = StandardScaler().fit(X_train)
#         y_scaler = StandardScaler().fit(y_train)
#         X_train_scaled = X_scaler.transform(X_train)
#         X_test_scaled = X_scaler.transform(X_test)
#         y_train_scaled = y_scaler.transform(y_train)
#         y_test_scaled = y_scaler.transform(y_test)
        train_scores = []
        test_scores = []
        for k in col:
            try:
                knn = KNeighborsClassifier(n_neighbors=k)
                knn.fit(X_train, y_train)
                train_score = knn.score(X_train, y_train)
                test_score = knn.score(X_test, y_test)
                train_scores.append(train_score)
                test_scores.append(test_score)
                print(f"k: {i} _ {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
            except ValueError:
                print(f"{i} skip in k dimension {k} value")
            except TypeError:
                print(f"{i} skip in k dimension {k} type")
    except ValueError:
        print(f"skip in i dimension {i}")
    except ValueError:
        print(f"skip in i dimension {i}")
# Out:
# date_time skip in k dimension date_time value
# date_time skip in k dimension power_delivered value
# date_time skip in k dimension energy_delivered value
# date_time skip in k dimension cumulative_energy value
# date_time skip in k dimension weather_description value
# date_time skip in k dimension clouds_all value
# date_time skip in k dimension temp_f value
# date_time skip in k dimension rain_1h value
# date_time skip in k dimension snow_1h value
# date_time skip in k dimension hour value
# date_time skip in k dimension day value
# date_time skip in k dimension month value
# power_delivered skip in k dimension date_time value
# power_delivered skip in k dimension power_delivered value
# power_delivered skip in k dimension energy_delivered value
# power_delivered skip in k dimension cumulative_energy value
# power_delivered skip in k dimension weather_description value
# power_delivered skip in k dimension clouds_all value
# power_delivered skip in k dimension temp_f value
# ...

# %%
# print(relationships)

# %%
# j = 0
# final = []
# for i in relationships:
#     current = i
# #     newlist = col
#     newlist = list(filter(lambda x: x != i, relationships))
# #     print(current)
# #     print(newlist)
# #     print(j)
#     j = j + 1
#     X = fiveaxis[newlist]
#     y = fiveaxis[current].values.reshape(-1,1)
#     X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#     X_scaler = StandardScaler().fit(X_train)
#     y_scaler = StandardScaler().fit(y_train)
#     X_train_scaled = X_scaler.transform(X_train)
#     X_test_scaled = X_scaler.transform(X_test)
#     y_train_scaled = y_scaler.transform(y_train)
#     y_test_scaled = y_scaler.transform(y_test)
#     model = LinearRegression()
#     model.fit(X_train_scaled, y_train_scaled)
#     predictions = model.predict(X_test_scaled)
#     MSE = mean_squared_error(y_test_scaled, predictions)
#     r2 = model.score(X_test_scaled, y_test_scaled)
#     if MSE != 0 and r2 != 1.0:
#       if MSE <= .1 and r2 >= .85:
#         final.append(current)
#     print(f"{current}, MSE: {MSE}, R2: {r2}")
# print(final)

# %%
# import pandas as pd
# import requests
# import datetime as dt
# from pprint import pprint

# %%
# import pandas as pd
# import requests
# import datetime as dt
# from pprint import pprint
# url = "https://api.sunrise-sunset.org/json?lat=44.986656&lng=-93.258133&date="
# # date = dt.date.today()
# date = fiveaxis['date_time'][0]

# response = requests.get(f"{url}{date}").json()
# pprint(response['results'])
# pprint(response['results']['day_length'])
# pprint(response['results']['sunrise'])
# pprint(response['results']['sunset'])

# %%
# print(date)

# %%
# for i in fiveaxis['date_time']:
#     date = i
#     response = requests.get(f"{url}{date}").json()
#     daylength = response['results']['day_length'] 
#     print(daylength)
# #         fiveaxis = fiveaxis.append(daylength)
# #     #     fiveaxis = fiveaxis.append(pd.io.json.json_normalize(response['results']['sunrise']))
# #     #     fiveaxis = fiveaxis.append(pd.io.json.json_normalize(response['results']['sunset']))
# # fiveaxis.head()
